# %% [markdown]
# <a href="https://colab.research.google.com/github/smack45/Password-and-Username-Generator/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(1/8 ,1.1, 2/8)
print('Tempo:', t)
m = 6*np.sin(2*np.pi*t)
print('Amostra:', m)

plt.plot(t,m)
plt.show()
# Out:
# Tempo: [0.125 0.375 0.625 0.875]
# Amostra: [ 4.24264069  4.24264069 -4.24264069 -4.24264069]

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(1/8,1.1,1/8)
print('Tempo:', t)

m = 6*np.sin(2*np.pi*t)
print('Amostra:', m)

plt.plot(t,m)
plt.show()
# Out:
# Tempo: [0.125 0.25  0.375 0.5   0.625 0.75  0.875 1.   ]
# Amostra: [ 4.24264069e+00  6.00000000e+00  4.24264069e+00  7.34788079e-16
#  -4.24264069e+00 -6.00000000e+00 -4.24264069e+00 -1.46957616e-15]

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(1/8,1.1,1/16)
print('Tempo:', t)

m = 6*np.sin(2*np.pi*t)
print('Amostra:', m)

plt.plot(t,m)
plt.show()
# Out:
# Tempo: [0.125  0.1875 0.25   0.3125 0.375  0.4375 0.5    0.5625 0.625  0.6875
#  0.75   0.8125 0.875  0.9375 1.     1.0625]
# Amostra: [ 4.24264069e+00  5.54327720e+00  6.00000000e+00  5.54327720e+00
#   4.24264069e+00  2.29610059e+00  7.34788079e-16 -2.29610059e+00
#  -4.24264069e+00 -5.54327720e+00 -6.00000000e+00 -5.54327720e+00
#  -4.24264069e+00 -2.29610059e+00 -1.46957616e-15  2.29610059e+00]
